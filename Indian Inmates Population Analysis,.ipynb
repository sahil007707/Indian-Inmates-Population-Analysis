# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import numpy as np

# %% [markdown]
# # Project
# # 📊 Indian Inmates Population Analysis By States
#
# ## 🧠 Data-Driven Storytelling: Exploring India's Prison Demographics
#
# This project dives into prison population data from Indian states and union territories, revealing important socio-political insights about incarceration trends across gender, state, and time. Let’s walk through the key findings using a storytelling approach.
#
# ---

# %%
df=pd.read_csv(r"f:\Downloads\Book 1(Sheet1).csv")

# %%
df.head()
# Out:
#             State/UT   Male  Female  Total
# 0     Andhra Pradesh  13414     899  14313
# 1  Arunachal Pradesh     90       2     92
# 2              Assam   7957     306   8263
# 3              Bihar  30159    1100  31259
# 4        Chhatisgarh  15019     821  15840

# %% [markdown]
# ## 📍 Introduction
#
# India's prison system is a reflection of its social, economic, and political structures. By analyzing inmate population data across states, we aim to answer critical questions:
#
# - Which states have the highest inmate populations?
# - How are inmates distributed across gender?
# - Are there outliers in prison data that need attention?
# - What categories (e.g., convicted vs undertrial) dominate the system?

# %% [markdown]
# ## Data Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   State/UT  36 non-null     object
#  1   Male      36 non-null     int64
#  2   Female    36 non-null     int64
#  3   Total     36 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.3+ KB

# %%
df.shape
# Out:
# (36, 4)

# %% [markdown]
# ## Data Handling & Cleaning

# %%
df.isna().sum()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.rename(columns={"State/UT":"States"})

# %% [markdown]
# ## EDA & Visualization

# %%
df.head()
# Out:
#               States   Male  Female  Total
# 0     Andhra Pradesh  13414     899  14313
# 1  Arunachal Pradesh     90       2     92
# 2              Assam   7957     306   8263
# 3              Bihar  30159    1100  31259
# 4        Chhatisgarh  15019     821  15840

# %%
classifi_p=df.groupby("States")[["Male","Female"]].sum().reset_index()
classifi_p
# Out:
#                States    Male  Female
# 0       A & N Islands    1141       8
# 1           All India  393804   18188
# 2      Andhra Pradesh   13414     899
# 3   Arunachal Pradesh      90       2
# 4               Assam    7957     306
# 5               Bihar   30159    1100
# 6          Chandigarh     637      24
# 7         Chhatisgarh   15019     821
# 8        D & N Haveli      35       0
# 9         Daman & Diu      55       1
# 10              Delhi   12937     615
# 11                Goa     495      28
# 12            Gujarat   11481     577
# 13            Haryana   16814     830
# 14   Himachal Pradesh    1903      96
# 15    Jammu & Kashmir    2265      87
# 16          Jharkhand   17370     850
# 17          Karnataka   13534     584
# 18             Kerala    7205     190
# 19        Lakshadweep       0       0
# 20     Madhya Pradesh   33622    1086
# 21        Maharashtra   25841    1559
# 22            Manipur     625      35
# 23          Meghalaya     839      11
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 6))  # Creating a figure with 2 subplots side by side
sns.set_style("whitegrid")

# First subplot
sns.barplot(data=classifi_p, x="States", y="Male", ax=axes[0])
axes[0].set_title("Male Inmates Distribution")
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

# Second subplot
sns.barplot(data=classifi_p, x="States", y="Female", ax=axes[1])
axes[1].set_title("Female Inmates Distribution")
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9752\476537690.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)
# C:\Users\user\AppData\Local\Temp\ipykernel_9752\476537690.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

# %% [markdown]
# ## Total Inmate Population Per States

# %%
df.head()
# Out:
#               States   Male  Female  Total
# 0     Andhra Pradesh  13414     899  14313
# 1  Arunachal Pradesh     90       2     92
# 2              Assam   7957     306   8263
# 3              Bihar  30159    1100  31259
# 4        Chhatisgarh  15019     821  15840

# %%
classifi_t=df.groupby("States")["Total"].sum().reset_index()
plt.figure(figsize=(15,6))
sns.barplot(data=classifi_t,x="States",y="Total",color="darkred")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 💡 Conclusion
#
# This analysis brings to light **systemic challenges** and **regional patterns** in India’s prison system:
#
# - 🚨 Over-reliance on under-trial imprisonment
# - 👥 Gender imbalance in inmate population
# - 🌐 State-level discrepancies in prison management
#
# ---
#
# ## 🛠 Tools Used
#
# - Python
# - Pandas, Matplotlib, Seaborn
# - Jupyter Notebook
#
# ---
#
# ## 📬 Author
#
# **Md Sahil Islam**
# ---
#
# ## ✅ Future Work
#
# - Time-series analysis to observe prison trends over years
# - Correlation between literacy, poverty, and inmate population
# - Machine learning classification on crime type vs demographics
#
# ---
